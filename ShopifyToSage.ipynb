# %%
import pandas as pd
import openpyxl

def get_customer_id(row):
    last_name = str(row['Billing Name']).rsplit(' ', maxsplit=1)[1][:3].upper()
    id_number = str(int(row['Id']))[-5:]
    return last_name + id_number

df = pd.read_csv("O:\Shopify\orders_export.csv", usecols=['Name','Email','Paid at','Shipping','Taxes','Total','Discount Code','Discount Amount','Shipping Method','Lineitem quantity','Lineitem name','Lineitem price','Lineitem sku','Billing Name','Billing Street','Billing Address1','Billing Address2','Billing City','Billing Zip','Billing Province','Billing Phone','Shipping Name','Shipping Address1','Shipping Address2','Shipping City','Shipping Zip','Shipping Province','Notes','Payment Method','Id','Risk Level'])
df = df.rename(columns={'Name':'Invoice Number','Paid at':'Date'})

# ffill order level data
df.sort_values(by='Invoice Number',inplace=True)
ffill_columns = ['Id','Date','Shipping Method','Billing Name','Billing Street','Billing Address1','Billing Address2','Billing City','Billing Zip','Billing Province','Billing Phone','Shipping Name','Shipping Address1','Shipping Address2','Shipping City','Shipping Zip','Shipping Province']
for col in ffill_columns:
    df[col] = df[col].ffill()

# fillna item level data
fillna_columns = ['Shipping','Taxes','Total','Discount Code','Discount Amount']
for col in fillna_columns:
    if df[col].dtype == "float64":
        df[col].fillna(0, inplace=True)
    else:
        df[col].fillna('', inplace=True)

df['Customer ID'] = df.apply(get_customer_id, axis=1)
df['Invoice Number'] = 'S' + df['Invoice Number'].str.strip('#')

# %%
df_customers = df[['Customer ID','Email','Discount Code','Shipping Method','Total','Billing Name','Billing Street','Billing Address1','Billing Address2','Billing City','Billing Zip','Billing Province','Billing Phone','Shipping Name','Shipping Address1','Shipping Address2','Shipping City','Shipping Zip','Shipping Province','Payment Method']].copy()



display(df_customers)
# Out:
#   Customer ID                   Email Discount Code  \
# 0    GLU86181    lisangluck@gmail.com
# 1    LAT33893   sslatchana1@gmail.com      KOLKER15
# 2    LAT33893   sslatchana1@gmail.com
# 3    LIC36453  rebeccafanya@yahoo.com       GAYLE15
# 4    LIC36453  rebeccafanya@yahoo.com
# 5    LIC36453  rebeccafanya@yahoo.com
#
#                       Shipping Method   Total         Billing Name  \
# 0        Standard (3-5 business days)  550.90           Lisa Gluck
# 1        Standard (3-5 business days)   91.91    Samantha Latchana
# 2        Standard (3-5 business days)    0.00    Samantha Latchana
# 3  FedEx 2nd Day (except Puerto Rico)  176.12  Rebecca Lichtenfeld
# 4  FedEx 2nd Day (except Puerto Rico)    0.00  Rebecca Lichtenfeld
# 5  FedEx 2nd Day (except Puerto Rico)    0.00  Rebecca Lichtenfeld
#
#              Billing Street    Billing Address1 Billing Address2  \
# 0  818 N Croft Ave, ApT 204     818 N Croft Ave          ApT 204
# ...
